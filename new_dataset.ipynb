# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# load dataset
df= pd.read_csv("faostat_csv")
df.head()
# Out:
#   Domain Code                             Domain  Area Code      Area  \
# 0          FS  Suite of Food Security Indicators        165  Pakistan
# 1          FS  Suite of Food Security Indicators        165  Pakistan
# 2          FS  Suite of Food Security Indicators        165  Pakistan
# 3          FS  Suite of Food Security Indicators        165  Pakistan
# 4          FS  Suite of Food Security Indicators        165  Pakistan
#
#    Element Code Element Item Code  \
# 0          6121   Value    210091
# 1          6121   Value   210091F
# 2          6121   Value   210091M
# 3          6121   Value    210091
# 4          6121   Value   210091F
#
#                                                 Item  Year Code       Year  \
# 0  Prevalence of moderate or severe food insecuri...   20142016  2014-2016
# 1  Prevalence of moderate or severe food insecuri...   20142016  2014-2016
# 2  Prevalence of moderate or severe food insecuri...   20142016  2014-2016
# ...

# %%
df.tail()
# Out:
#    Domain Code                             Domain  Area Code      Area  \
# 13          FS  Suite of Food Security Indicators        165  Pakistan
# 14          FS  Suite of Food Security Indicators        165  Pakistan
# 15          FS  Suite of Food Security Indicators        165  Pakistan
# 16          FS  Suite of Food Security Indicators        165  Pakistan
# 17          FS  Suite of Food Security Indicators        165  Pakistan
#
#     Element Code Element Item Code  \
# 13          6121   Value   210091F
# 14          6121   Value   210091M
# 15          6121   Value    210091
# 16          6121   Value   210091F
# 17          6121   Value   210091M
#
#                                                  Item  Year Code       Year  \
# 13  Prevalence of moderate or severe food insecuri...   20182020  2018-2020
# 14  Prevalence of moderate or severe food insecuri...   20182020  2018-2020
# 15  Prevalence of moderate or severe food insecuri...   20192021  2019-2021
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=18, step=1)

# %%
dates = pd.date_range("2014","2021")
dates
# Out:
# DatetimeIndex(['2014-01-01', '2014-01-02', '2014-01-03', '2014-01-04',
#                '2014-01-05', '2014-01-06', '2014-01-07', '2014-01-08',
#                '2014-01-09', '2014-01-10',
#                ...
#                '2020-12-23', '2020-12-24', '2020-12-25', '2020-12-26',
#                '2020-12-27', '2020-12-28', '2020-12-29', '2020-12-30',
#                '2020-12-31', '2021-01-01'],
#               dtype='datetime64[ns]', length=2558, freq='D')

# %%
import numpy as np
x = np.array([1,2,5,6,7,8,9,4])
x
# Out:
# array([1, 2, 5, 6, 7, 8, 9, 4])

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("faostat_csv")
df
# Out:
#    Domain Code                             Domain  Area Code      Area  \
# 0           FS  Suite of Food Security Indicators        165  Pakistan
# 1           FS  Suite of Food Security Indicators        165  Pakistan
# 2           FS  Suite of Food Security Indicators        165  Pakistan
# 3           FS  Suite of Food Security Indicators        165  Pakistan
# 4           FS  Suite of Food Security Indicators        165  Pakistan
# 5           FS  Suite of Food Security Indicators        165  Pakistan
# 6           FS  Suite of Food Security Indicators        165  Pakistan
# 7           FS  Suite of Food Security Indicators        165  Pakistan
# 8           FS  Suite of Food Security Indicators        165  Pakistan
# 9           FS  Suite of Food Security Indicators        165  Pakistan
# 10          FS  Suite of Food Security Indicators        165  Pakistan
# 11          FS  Suite of Food Security Indicators        165  Pakistan
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Domain Code       18 non-null     object
#  1   Domain            18 non-null     object
#  2   Area Code         18 non-null     int64
#  3   Area              18 non-null     object
#  4   Element Code      18 non-null     int64
#  5   Element           18 non-null     object
#  6   Item Code         18 non-null     object
#  7   Item              18 non-null     object
#  8   Year Code         18 non-null     int64
#  9   Year              18 non-null     object
#  10  Unit              18 non-null     object
#  11  Value             18 non-null     float64
#  12  Flag              12 non-null     object
#  13  Flag Description  18 non-null     object
#  14  Note              6 non-null      object
# dtypes: float64(1), int64(3), object(11)
# memory usage: 2.2+ KB

# %%
df.isnull().sum()
# Out:
# Domain Code          0
# Domain               0
# Area Code            0
# Area                 0
# Element Code         0
# Element              0
# Item Code            0
# Item                 0
# Year Code            0
# Year                 0
# Unit                 0
# Value                0
# Flag                 6
# Flag Description     0
# Note                12
# dtype: int64

# %%
df["Year"].unique()
# Out:
# array(['2014-2016', '2015-2017', '2016-2018', '2017-2019', '2018-2020',
#        '2019-2021'], dtype=object)

# %%
df["Item"].unique()
# Out:
# array(['Prevalence of moderate or severe food insecurity in the total population (percent) (3-year average)',
#        'Prevalence of moderate or severe food insecurity in the female adult population (percent) (3-year average)',
#        'Prevalence of moderate or severe food insecurity in the male adult population (percent) (3-year average)'],
#       dtype=object)

# %%
df["Item"].value_counts()
# Out:
# Prevalence of moderate or severe food insecurity in the total population (percent) (3-year average)           6
# Prevalence of moderate or severe food insecurity in the female adult population (percent) (3-year average)    6
# Prevalence of moderate or severe food insecurity in the male adult population (percent) (3-year average)      6
# Name: Item, dtype: int64

# %%
df["Element"].unique()
# Out:
# array(['Value'], dtype=object)

# %%
df["Item"].value_counts().head()
# Out:
# Prevalence of moderate or severe food insecurity in the total population (percent) (3-year average)           6
# Prevalence of moderate or severe food insecurity in the female adult population (percent) (3-year average)    6
# Prevalence of moderate or severe food insecurity in the male adult population (percent) (3-year average)      6
# Name: Item, dtype: int64

# %%
df = df.sort_values("Value", ascending = False).head(20)

# %%
df.value_counts()
# Out:
# Series([], dtype: int64)

# %%
df.to_numpy()
# Out:
# array([['FS', 'Suite of Food Security Indicators', 165, 'Pakistan', 6121,
#         'Value', '210091F',
#         'Prevalence of moderate or severe food insecurity in the female adult population (percent) (3-year average)',
#         20192021, '2019-2021', '%', 45.0, 'F', 'FAO estimate', nan],
#        ['FS', 'Suite of Food Security Indicators', 165, 'Pakistan', 6121,
#         'Value', '210091F',
#         'Prevalence of moderate or severe food insecurity in the female adult population (percent) (3-year average)',
#         20182020, '2018-2020', '%', 42.7, 'F', 'FAO estimate', nan],
#        ['FS', 'Suite of Food Security Indicators', 165, 'Pakistan', 6121,
#         'Value', '210091F',
#         'Prevalence of moderate or severe food insecurity in the female adult population (percent) (3-year average)',
#         20142016, '2014-2016', '%', 37.8, 'F', 'FAO estimate', nan],
#        ['FS', 'Suite of Food Security Indicators', 165, 'Pakistan', 6121,
#         'Value', '210091M',
# ...

# %%
df.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of    Domain Code                             Domain  Area Code      Area  \
# 16          FS  Suite of Food Security Indicators        165  Pakistan
# 13          FS  Suite of Food Security Indicators        165  Pakistan
# 1           FS  Suite of Food Security Indicators        165  Pakistan
# 17          FS  Suite of Food Security Indicators        165  Pakistan
# 10          FS  Suite of Food Security Indicators        165  Pakistan
# 14          FS  Suite of Food Security Indicators        165  Pakistan
# 7           FS  Suite of Food Security Indicators        165  Pakistan
# 15          FS  Suite of Food Security Indicators        165  Pakistan
# 4           FS  Suite of Food Security Indicators        165  Pakistan
# 11          FS  Suite of Food Security Indicators        165  Pakistan
# 2           FS  Suite of Food Security Indicators        165  Pakistan
# ...

# %%
df.T
# Out:
#                                                                  16  \
# Domain Code                                                      FS
# Domain                            Suite of Food Security Indicators
# Area Code                                                       165
# Area                                                       Pakistan
# Element Code                                                   6121
# Element                                                       Value
# Item Code                                                   210091F
# Item              Prevalence of moderate or severe food insecuri...
# Year Code                                                  20192021
# Year                                                      2019-2021
# Unit                                                              %
# Value                                                          45.0
# Flag                                                              F
# ...

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#     Year Code       Year  Value Unit  \
# 16   20192021  2019-2021   45.0    %
# 13   20182020  2018-2020   42.7    %
# 1    20142016  2014-2016   37.8    %
# 17   20192021  2019-2021   37.7    %
# 10   20172019  2017-2019   37.7    %
# 14   20182020  2018-2020   37.0    %
# 7    20162018  2016-2018   34.6    %
# 15   20192021  2019-2021   32.6    %
# 4    20152017  2015-2017   32.5    %
# 11   20172019  2017-2019   30.4    %
# 2    20142016  2014-2016   27.4    %
# 8    20162018  2016-2018   25.1    %
# 12   20182020  2018-2020   24.3    %
# 5    20152017  2015-2017   23.6    %
# 9    20172019  2017-2019   14.2    %
# 0    20142016  2014-2016   14.0    %
# 6    20162018  2016-2018   12.8    %
# 3    20152017  2015-2017   12.1    %
#
#                                           Note Item Code  \
# 16                                         NaN   210091F
# 13                                         NaN   210091F
# 1                                          NaN   210091F
# ...

# %%
df.sort_index(axis=0, ascending=True)
# Out:
#    Domain Code                             Domain  Area Code      Area  \
# 0           FS  Suite of Food Security Indicators        165  Pakistan
# 1           FS  Suite of Food Security Indicators        165  Pakistan
# 2           FS  Suite of Food Security Indicators        165  Pakistan
# 3           FS  Suite of Food Security Indicators        165  Pakistan
# 4           FS  Suite of Food Security Indicators        165  Pakistan
# 5           FS  Suite of Food Security Indicators        165  Pakistan
# 6           FS  Suite of Food Security Indicators        165  Pakistan
# 7           FS  Suite of Food Security Indicators        165  Pakistan
# 8           FS  Suite of Food Security Indicators        165  Pakistan
# 9           FS  Suite of Food Security Indicators        165  Pakistan
# 10          FS  Suite of Food Security Indicators        165  Pakistan
# 11          FS  Suite of Food Security Indicators        165  Pakistan
# ...

# %%
df.sort_values(by="Value", ascending=False)
# Out:
#    Domain Code                             Domain  Area Code      Area  \
# 16          FS  Suite of Food Security Indicators        165  Pakistan
# 13          FS  Suite of Food Security Indicators        165  Pakistan
# 1           FS  Suite of Food Security Indicators        165  Pakistan
# 17          FS  Suite of Food Security Indicators        165  Pakistan
# 10          FS  Suite of Food Security Indicators        165  Pakistan
# 14          FS  Suite of Food Security Indicators        165  Pakistan
# 7           FS  Suite of Food Security Indicators        165  Pakistan
# 15          FS  Suite of Food Security Indicators        165  Pakistan
# 4           FS  Suite of Food Security Indicators        165  Pakistan
# 11          FS  Suite of Food Security Indicators        165  Pakistan
# 2           FS  Suite of Food Security Indicators        165  Pakistan
# 8           FS  Suite of Food Security Indicators        165  Pakistan
# ...

# %%
df["Flag"]
# Out:
# 16      F
# 13      F
# 1       F
# 17      F
# 10      F
# 14      F
# 7       F
# 15    NaN
# 4       F
# 11      F
# 2       F
# 8       F
# 12    NaN
# 5       F
# 9     NaN
# 0     NaN
# 6     NaN
# 3     NaN
# Name: Flag, dtype: object

# %%
df[0:6]
# Out:
#    Domain Code                             Domain  Area Code      Area  \
# 16          FS  Suite of Food Security Indicators        165  Pakistan
# 13          FS  Suite of Food Security Indicators        165  Pakistan
# 1           FS  Suite of Food Security Indicators        165  Pakistan
# 17          FS  Suite of Food Security Indicators        165  Pakistan
# 10          FS  Suite of Food Security Indicators        165  Pakistan
# 14          FS  Suite of Food Security Indicators        165  Pakistan
#
#     Element Code Element Item Code  \
# 16          6121   Value   210091F
# 13          6121   Value   210091F
# 1           6121   Value   210091F
# 17          6121   Value   210091M
# 10          6121   Value   210091F
# 14          6121   Value   210091M
#
#                                                  Item  Year Code       Year  \
# 16  Prevalence of moderate or severe food insecuri...   20192021  2019-2021
# ...

# %%
df.loc[:,["Domain","Note"]]
# Out:
#                                Domain  \
# 16  Suite of Food Security Indicators
# 13  Suite of Food Security Indicators
# 1   Suite of Food Security Indicators
# 17  Suite of Food Security Indicators
# 10  Suite of Food Security Indicators
# 14  Suite of Food Security Indicators
# 7   Suite of Food Security Indicators
# 15  Suite of Food Security Indicators
# 4   Suite of Food Security Indicators
# 11  Suite of Food Security Indicators
# 2   Suite of Food Security Indicators
# 8   Suite of Food Security Indicators
# 12  Suite of Food Security Indicators
# 5   Suite of Food Security Indicators
# 9   Suite of Food Security Indicators
# 0   Suite of Food Security Indicators
# 6   Suite of Food Security Indicators
# 3   Suite of Food Security Indicators
#
#                                           Note
# 16                                         NaN
# 13                                         NaN
# 1                                          NaN
# ...

# %%
df.iloc[3:10]
# Out:
#    Domain Code                             Domain  Area Code      Area  \
# 17          FS  Suite of Food Security Indicators        165  Pakistan
# 10          FS  Suite of Food Security Indicators        165  Pakistan
# 14          FS  Suite of Food Security Indicators        165  Pakistan
# 7           FS  Suite of Food Security Indicators        165  Pakistan
# 15          FS  Suite of Food Security Indicators        165  Pakistan
# 4           FS  Suite of Food Security Indicators        165  Pakistan
# 11          FS  Suite of Food Security Indicators        165  Pakistan
#
#     Element Code Element Item Code  \
# 17          6121   Value   210091M
# 10          6121   Value   210091F
# 14          6121   Value   210091M
# 7           6121   Value   210091F
# 15          6121   Value    210091
# 4           6121   Value   210091F
# 11          6121   Value   210091M
#
#                                                  Item  Year Code       Year  \
# ...

# %%
df = df.copy()

# %%
df["Mean"] = ["1","2","1","3","2","4","5","6","7","0","7","7","5","1","12","16","17","18"]
df
# Out:
#    Domain Code                             Domain  Area Code      Area  \
# 16          FS  Suite of Food Security Indicators        165  Pakistan
# 13          FS  Suite of Food Security Indicators        165  Pakistan
# 1           FS  Suite of Food Security Indicators        165  Pakistan
# 17          FS  Suite of Food Security Indicators        165  Pakistan
# 10          FS  Suite of Food Security Indicators        165  Pakistan
# 14          FS  Suite of Food Security Indicators        165  Pakistan
# 7           FS  Suite of Food Security Indicators        165  Pakistan
# 15          FS  Suite of Food Security Indicators        165  Pakistan
# 4           FS  Suite of Food Security Indicators        165  Pakistan
# 11          FS  Suite of Food Security Indicators        165  Pakistan
# 2           FS  Suite of Food Security Indicators        165  Pakistan
# 8           FS  Suite of Food Security Indicators        165  Pakistan
# ...

# %%
import pandas as pd

df = pd.DataFrame({"Index","Domain Code","Domain","Area Code","Area","Element Code","Element","ItemCode","Item","Year Code","Year","Unit","Value","Flag","Flag Description","Note"})
print("Index","Domain Code","Domain","Area Code","Area","Element Code","Element","ItemCode","Item","Year Code","Year","Unit","Value","Flag","Flag Description","Note")
print(df)
del df
# Out:
# Index Domain Code Domain Area Code Area Element Code Element ItemCode Item Year Code Year Unit Value Flag Flag Description Note
#                    0
# 0               Note
# 1               Unit
# 2          Area Code
# 3        Domain Code
# 4               Flag
# 5              Value
# 6            Element
# 7       Element Code
# 8             Domain
# 9               Area
# 10             Index
# 11              Year
# 12  Flag Description
# 13              Item
# 14          ItemCode
# 15         Year Code

# %%
df = pd.read_csv("faostat_csv")
df
# Out:
#    Domain Code                             Domain  Area Code      Area  \
# 0           FS  Suite of Food Security Indicators        165  Pakistan
# 1           FS  Suite of Food Security Indicators        165  Pakistan
# 2           FS  Suite of Food Security Indicators        165  Pakistan
# 3           FS  Suite of Food Security Indicators        165  Pakistan
# 4           FS  Suite of Food Security Indicators        165  Pakistan
# 5           FS  Suite of Food Security Indicators        165  Pakistan
# 6           FS  Suite of Food Security Indicators        165  Pakistan
# 7           FS  Suite of Food Security Indicators        165  Pakistan
# 8           FS  Suite of Food Security Indicators        165  Pakistan
# 9           FS  Suite of Food Security Indicators        165  Pakistan
# 10          FS  Suite of Food Security Indicators        165  Pakistan
# 11          FS  Suite of Food Security Indicators        165  Pakistan
# ...

# %%
import seaborn as sns

sns.catplot(x='Year', y='Value', hue='Item', kind='bar', data=df, legend=False,height=7,palette=['tab:blue', 'tab:green', 'tab:orange', 'tab:red']) 
plt.xlabel('', size=17)
plt.ylabel('%', size=17)
# Out:
# Text(10.050000000000004, 0.5, '%')
